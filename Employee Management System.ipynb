# %%
The Goal: Create a base Employee class with the attributes name and base_salary. Include a method called calculate_pay() that simply returns the base salary.
# Out:
#   Cell In[1], line 1
#     The Goal: Create a base Employee class with the attributes name and base_salary. Include a method called calculate_pay() that simply returns the base salary.
#         ^
# SyntaxError: invalid syntax

# %%
class Employee:
    def __init__(self, name, base_salary):
        self.name = name
        self.base_salary = base_salary
    def calculate_pay(self):
        return self.base_salary
class Manager(Employee):
    def __init__(self, name, base_salary, bonus):
        super().__init__(name, base_salary)
        self.bonus = bonus
    def caculate_pay(self):
        return self.base_salary + self.bonus
class Developer(Employee):
    def __init__(self, name, base_salary, programming_language):
        super().__init__(name, base_salary)
        self.programming_language = programming_language
    def caculate_pay(self):
        return self.base_salary
    def write_code(self):
        print(f"{self.name} is writing code in {self.programming_language}")
emp = Employee("John",750)
print("Employee Pay:", emp.calculate_pay())
mgr = Manager("Bran",1000, 500)
print("Manager Pay:",mgr.caculate_pay())
dev = Developer("Sok",500, "Python")
print("Developer Pay:",dev.caculate_pay())
dev.write_code()
# Out:
# Employee Pay: 750
# Manager Pay: 1500
# Developer Pay: 500
# Sok is writing code in Python
